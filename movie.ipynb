# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  ...  OpSys  Weight        Price
# 0           0   Apple  Ultrabook  ...  macOS  1.37kg   71378.6832
# 1           1   Apple  Ultrabook  ...  macOS  1.34kg   47895.5232
# 2           2      HP   Notebook  ...  No OS  1.86kg   30636.0000
# 3           3   Apple  Ultrabook  ...  macOS  1.83kg  135195.3360
# 4           4   Apple  Ultrabook  ...  macOS  1.37kg   96095.8080
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["Unnamed: 0"] , inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df["Ram"]=df["Ram"].str.replace("GB","")
df["Weight"]=df["Weight"].str.replace("kg","")

# %%
df.sample(5)
# Out:
#       Company            TypeName  Inches  ...       OpSys Weight      Price
# 1150   Lenovo            Notebook    15.6  ...       No OS    1.9  18061.920
# 1004  Toshiba            Notebook    13.3  ...  Windows 10    1.2  63669.600
# 1126   Lenovo  2 in 1 Convertible    10.1  ...  Windows 10   0.69  25521.120
# 13       Dell            Notebook    15.6  ...  Windows 10    2.2  26581.392
# 879        HP            Notebook    15.6  ...  Windows 10   2.04  44701.920
#
# [5 rows x 11 columns]

# %%
df["Ram"]=df["Ram"].astype("int")
df["Weight"]=df["Weight"].astype("float")
df["Price"]=df["Price"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 112.1+ KB

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches  ...       OpSys Weight  Price
# 1076  Lenovo  Notebook    15.6  ...  Windows 10   2.30  52054
# 305   Lenovo  Notebook    15.6  ...       No OS   2.20  19180
# 1282      HP   Netbook    11.6  ...  Windows 10   1.17  11135
# 1232    Dell  Notebook    15.6  ...  Windows 10   2.30  24988
# 527   Lenovo  Notebook    15.6  ...       No OS   2.20  24455
#
# [5 rows x 11 columns]

# %%
df['Company'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
import seaborn as sns

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4476\941010651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
#  # price column  is left skewed

# %%
sns.barplot(x=df["Company"] , y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
df["TouchScreen"]=df["ScreenResolution"].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df["TouchScreen"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
df["IPS"]=df["ScreenResolution"].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ...   Price TouchScreen  IPS
# 0   Apple  Ultrabook    13.3  ...   71378           0    1
# 1   Apple  Ultrabook    13.3  ...   47895           0    0
# 2      HP   Notebook    15.6  ...   30636           0    0
# 3   Apple  Ultrabook    15.4  ...  135195           0    1
# 4   Apple  Ultrabook    13.3  ...   96095           0    1
#
# [5 rows x 13 columns]

# %%
new=df['ScreenResolution'].str.split("x",n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['x_res']=new[0]
df['y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ... IPS                          x_res  y_res
# 0   Apple  Ultrabook    13.3  ...   1  IPS Panel Retina Display 2560   1600
# 1   Apple  Ultrabook    13.3  ...   0                           1440    900
# 2      HP   Notebook    15.6  ...   0                   Full HD 1920   1080
# 3   Apple  Ultrabook    15.4  ...   1  IPS Panel Retina Display 2880   1800
# 4   Apple  Ultrabook    13.3  ...   1  IPS Panel Retina Display 2560   1600
#
# [5 rows x 15 columns]

# %%
df['x_res']=df['x_res'].str.replace(',',"").str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ... IPS x_res  y_res
# 0   Apple  Ultrabook    13.3  ...   1  2560   1600
# 1   Apple  Ultrabook    13.3  ...   0  1440    900
# 2      HP   Notebook    15.6  ...   0  1920   1080
# 3   Apple  Ultrabook    15.4  ...   1  2880   1800
# 4   Apple  Ultrabook    13.3  ...   1  2560   1600
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 152.8+ KB

# %%
df['x_res']=df['x_res'].astype(int)
df['y_res']=df['y_res'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int64
#  14  y_res             1303 non-null   int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 152.8+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                Inches       Ram    Weight  ...       IPS     x_res     y_res
# Inches       1.000000  0.237993  0.827631  ... -0.114804 -0.071245 -0.095404
# Ram          0.237993  1.000000  0.383874  ...  0.206623  0.433121  0.424437
# Weight       0.827631  0.383874  1.000000  ...  0.016967 -0.032880 -0.053846
# Price        0.068196  0.743007  0.210370  ...  0.252207  0.556529  0.552809
# TouchScreen -0.361735  0.116984 -0.294620  ...  0.150512  0.351066  0.357930
# IPS         -0.114804  0.206623  0.016967  ...  1.000000  0.281457  0.289030
# x_res       -0.071245  0.433121 -0.032880  ...  0.281457  1.000000  0.994219
# y_res       -0.095404  0.424437 -0.053846  ...  0.289030  0.994219  1.000000
#
# [8 rows x 8 columns]

# %%
df['ppi']=(((df['x_res']**2)+(df['y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ... x_res y_res         ppi
# 0   Apple  Ultrabook    13.3  ...  2560  1600  226.983005
# 1   Apple  Ultrabook    13.3  ...  1440   900  127.677940
# 2      HP   Notebook    15.6  ...  1920  1080  141.211998
# 3   Apple  Ultrabook    15.4  ...  2880  1800  220.534624
# 4   Apple  Ultrabook    13.3  ...  2560  1600  226.983005
#
# [5 rows x 16 columns]

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS            0.252207
# x_res          0.556529
# y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches',"x_res","y_res","ScreenResolution"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  ...  TouchScreen IPS         ppi
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz  ...            0   1  226.983005
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz  ...            0   0  127.677940
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz  ...            0   0  141.211998
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  ...            0   1  220.534624
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz  ...            0   1  226.983005
#
# [5 rows x 12 columns]

# %%
df["ProcessorName"]=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  ...         ppi  ProcessorName
# 0   Apple  Ultrabook  ...  226.983005  Intel Core i5
# 1   Apple  Ultrabook  ...  127.677940  Intel Core i5
# 2      HP   Notebook  ...  141.211998  Intel Core i5
# 3   Apple  Ultrabook  ...  220.534624  Intel Core i7
# 4   Apple  Ultrabook  ...  226.983005  Intel Core i5
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Cpu            1303 non-null   object
#  3   Ram            1303 non-null   int64
#  4   Memory         1303 non-null   object
#  5   Gpu            1303 non-null   object
#  6   OpSys          1303 non-null   object
#  7   Weight         1303 non-null   float64
#  8   Price          1303 non-null   int64
#  9   TouchScreen    1303 non-null   int64
#  10  IPS            1303 non-null   int64
#  11  ppi            1303 non-null   float64
#  12  ProcessorName  1303 non-null   object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 132.5+ KB

# %%
def fetch_processor(text):
    if text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3":
        return text
    else :
        if text.split()[0] == "Intel":
            return "Other Intel Processor"
        else: 
            return "Amd processor"

# %%
df["Processor"]=df["ProcessorName"].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName  ...  ProcessorName      Processor
# 0   Apple  Ultrabook  ...  Intel Core i5  Intel Core i5
# 1   Apple  Ultrabook  ...  Intel Core i5  Intel Core i5
# 2      HP   Notebook  ...  Intel Core i5  Intel Core i5
# 3   Apple  Ultrabook  ...  Intel Core i7  Intel Core i7
# 4   Apple  Ultrabook  ...  Intel Core i5  Intel Core i5
#
# [5 rows x 14 columns]

# %%
df["Processor"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Processor'>

# %%
sns.barplot(x=df["Processor"],  y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Cpu            1303 non-null   object
#  3   Ram            1303 non-null   int64
#  4   Memory         1303 non-null   object
#  5   Gpu            1303 non-null   object
#  6   OpSys          1303 non-null   object
#  7   Weight         1303 non-null   float64
#  8   Price          1303 non-null   int64
#  9   TouchScreen    1303 non-null   int64
#  10  IPS            1303 non-null   int64
#  11  ppi            1303 non-null   float64
#  12  ProcessorName  1303 non-null   object
#  13  Processor      1303 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 142.6+ KB

# %%
df.drop(columns=['ProcessorName','Cpu'] , inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  ... IPS         ppi      Processor
# 0   Apple  Ultrabook    8  ...   1  226.983005  Intel Core i5
# 1   Apple  Ultrabook    8  ...   0  127.677940  Intel Core i5
# 2      HP   Notebook    8  ...   0  141.211998  Intel Core i5
# 3   Apple  Ultrabook   16  ...   1  220.534624  Intel Core i7
# 4   Apple  Ultrabook    8  ...   1  226.983005  Intel Core i5
#
# [5 rows x 12 columns]

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '',regex=True)

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '',regex=True)

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4476\1000839292.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  ... HDD  SSD  Hybrid  Flash_Storage
# 0   Apple  Ultrabook    8            128 SSD  ...   0  128       0              0
# 1   Apple  Ultrabook    8  128 Flash Storage  ...   0    0       0            128
# 2      HP   Notebook    8            256 SSD  ...   0  256       0              0
# 3   Apple  Ultrabook   16            512 SSD  ...   0  512       0              0
# 4   Apple  Ultrabook    8            256 SSD  ...   0  256       0              0
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Ram            1303 non-null   int64
#  3   Memory         1303 non-null   object
#  4   Gpu            1303 non-null   object
#  5   OpSys          1303 non-null   object
#  6   Weight         1303 non-null   float64
#  7   Price          1303 non-null   int64
#  8   TouchScreen    1303 non-null   int64
#  9   IPS            1303 non-null   int64
#  10  ppi            1303 non-null   float64
#  11  Processor      1303 non-null   object
#  12  HDD            1303 non-null   int64
#  13  SSD            1303 non-null   int64
#  14  Hybrid         1303 non-null   int64
#  15  Flash_Storage  1303 non-null   int64
# dtypes: float64(2), int64(8), object(6)
# memory usage: 163.0+ KB

# %%
df.sample(5)
# Out:
#     Company  TypeName  Ram  ...  SSD Hybrid Flash_Storage
# 184  Xiaomi  Notebook    8  ...  256      0             0
# 362  Lenovo  Notebook    6  ...  128      0             0
# 997    Acer  Notebook    4  ...    0      0             0
# 897      HP  Notebook    8  ...    0      0             0
# 769    Acer  Notebook    4  ...    0      0             0
#
# [5 rows x 16 columns]

# %%
df.drop(columns=["Hybrid","Flash_Storage"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  ...      Processor HDD  SSD
# 0   Apple  Ultrabook    8  ...  Intel Core i5   0  128
# 1   Apple  Ultrabook    8  ...  Intel Core i5   0    0
# 2      HP   Notebook    8  ...  Intel Core i5   0  256
# 3   Apple  Ultrabook   16  ...  Intel Core i7   0  512
# 4   Apple  Ultrabook    8  ...  Intel Core i5   0  256
#
# [5 rows x 14 columns]

# %%
df['GpuBrand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  ...      Processor HDD  SSD  GpuBrand
# 0   Apple  Ultrabook    8            128 SSD  ...  Intel Core i5   0  128     Intel
# 1   Apple  Ultrabook    8  128 Flash Storage  ...  Intel Core i5   0    0     Intel
# 2      HP   Notebook    8            256 SSD  ...  Intel Core i5   0  256     Intel
# 3   Apple  Ultrabook   16            512 SSD  ...  Intel Core i7   0  512       AMD
# 4   Apple  Ultrabook    8            256 SSD  ...  Intel Core i5   0  256     Intel
#
# [5 rows x 15 columns]

# %%
df.drop(columns=['Gpu','Memory'],inplace=True)

# %%
df['GpuBrand'].value_counts()
# Out:
# GpuBrand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS            0.252207
# ppi            0.473487
# HDD           -0.096442
# SSD            0.670799
# Name: Price, dtype: float64

# %%
sns.barplot(x=df['GpuBrand'] , y=df["Price"] )
# Out:
# <Axes: xlabel='GpuBrand', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  ...      Processor  HDD  SSD  GpuBrand
# 0   Apple  Ultrabook    8  macOS  ...  Intel Core i5    0  128     Intel
# 1   Apple  Ultrabook    8  macOS  ...  Intel Core i5    0    0     Intel
# 2      HP   Notebook    8  No OS  ...  Intel Core i5    0  256     Intel
# 3   Apple  Ultrabook   16  macOS  ...  Intel Core i7    0  512       AMD
# 4   Apple  Ultrabook    8  macOS  ...  Intel Core i5    0  256     Intel
#
# [5 rows x 13 columns]

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def os_cat(inp):
    if inp == "Windows 10" or inp== "Windows 7" or inp=="Windows 10 S":
        return "Windows"
    elif inp== "macOS" or inp=="Mac OS X":
        return 'Mac'
    else:
        return "Other/No os/ Linux"

# %%
df['os']=df['OpSys'].apply(os_cat)

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df['os'].value_counts()
# Out:
# os
# Windows               1125
# Other/No os/ Linux     157
# Mac                     21
# Name: count, dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
import numpy as np

# %%
x=df.drop(columns=["Price"])

# %%
x.head()
# Out:
#   Company   TypeName  Ram  Weight  ...  HDD  SSD  GpuBrand                  os
# 0   Apple  Ultrabook    8    1.37  ...    0  128     Intel                 Mac
# 1   Apple  Ultrabook    8    1.34  ...    0    0     Intel                 Mac
# 2      HP   Notebook    8    1.86  ...    0  256     Intel  Other/No os/ Linux
# 3   Apple  Ultrabook   16    1.83  ...    0  512       AMD                 Mac
# 4   Apple  Ultrabook    8    1.37  ...    0  256     Intel                 Mac
#
# [5 rows x 12 columns]

# %%
y=np.log(df["Price"])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (1042, 12)

# %%
x_train.head()
# Out:
#      Company   TypeName  Ram  Weight  ...   HDD  SSD  GpuBrand                  os
# 10        HP   Notebook    4    1.86  ...   500    0     Intel  Other/No os/ Linux
# 147     Asus   Notebook    4    2.00  ...  1000    0     Intel             Windows
# 1287      HP   Notebook    6    2.19  ...  1000    0       AMD             Windows
# 767     Dell     Gaming   16    2.72  ...  1000  128    Nvidia             Windows
# 816    Razer  Ultrabook   16    1.29  ...     0  512     Intel             Windows
#
# [5 rows x 12 columns]

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\lenovo\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (1.16.3)

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
one_hot_column_transformer=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])],remainder="passthrough")
model=LinearRegression()

pipe=Pipeline([("one_hot_column_transformer",one_hot_column_transformer),('model',model)])

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight  ...  HDD  SSD  GpuBrand                  os
# 0   Apple  Ultrabook    8    1.37  ...    0  128     Intel                 Mac
# 1   Apple  Ultrabook    8    1.34  ...    0    0     Intel                 Mac
# 2      HP   Notebook    8    1.86  ...    0  256     Intel  Other/No os/ Linux
# 3   Apple  Ultrabook   16    1.83  ...    0  512       AMD                 Mac
# 4   Apple  Ultrabook    8    1.37  ...    0  256     Intel                 Mac
#
# [5 rows x 13 columns]

# %%
x_train.head()
# Out:
#      Company   TypeName  Ram  Weight  ...   HDD  SSD  GpuBrand                  os
# 10        HP   Notebook    4    1.86  ...   500    0     Intel  Other/No os/ Linux
# 147     Asus   Notebook    4    2.00  ...  1000    0     Intel             Windows
# 1287      HP   Notebook    6    2.19  ...  1000    0       AMD             Windows
# 767     Dell     Gaming   16    2.72  ...  1000  128    Nvidia             Windows
# 816    Razer  Ultrabook   16    1.29  ...     0  512     Intel             Windows
#
# [5 rows x 12 columns]

# %%
x_train['os'].value_counts()
# Out:
# os
# Windows               896
# Other/No os/ Linux    127
# Mac                    19
# Name: count, dtype: int64

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1042 entries, 10 to 1126
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1042 non-null   object
#  1   TypeName     1042 non-null   object
#  2   Ram          1042 non-null   int64
#  3   Weight       1042 non-null   float64
#  4   TouchScreen  1042 non-null   int64
#  5   IPS          1042 non-null   int64
#  6   ppi          1042 non-null   float64
#  7   Processor    1042 non-null   object
#  8   HDD          1042 non-null   int64
#  9   SSD          1042 non-null   int64
#  10  GpuBrand     1042 non-null   object
#  11  os           1042 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 105.8+ KB

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('one_hot_column_transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 7, 10, 11])])),
#                 ('model', LinearRegression())])

# %%
pred=pipe.predict(x_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.8255531017745003

# %%
mean_absolute_error(y_test,pred)
# Out:
# 0.19596623423982598

# %%
import pickle 
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
